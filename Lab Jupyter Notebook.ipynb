# %% [markdown]
# # Me Myself and I

# %% [markdown]
# The purpose of this notebook is to introduce myself and give you my holiday preferences with a pic an d a youtube link.

# %%
def f():
    name = input ("Please introduce the person:")
    
    return name

# %% [markdown]
# ![pp.jpeg](attachment:pp.jpeg)

# %%
def f():
    HolidayPreference = input ("Do you prefer the Beach or the Mountains?:")
    
    return HolidayPreference

# %% [markdown]
# ![Riedberpass_Ho%CC%88rnergruppe_Allga%CC%88uer_Alpen_-_Stefan_Schurr_stock.adobe.com.jpeg](attachment:Riedberpass_Ho%CC%88rnergruppe_Allga%CC%88uer_Alpen_-_Stefan_Schurr_stock.adobe.com.jpeg)

# %% [markdown]
# # Top 3 Activities
#
# + **Hiking**
# + *Climbing*
# + **Sledging**

# %%
from IPython.display import HTML

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/mICnwJVujAs;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/mICnwJVujAs;showinfo=0" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# How to add a youtube video, how to set bullet points and how to add a picture.
